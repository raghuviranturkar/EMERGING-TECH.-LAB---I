# %% [markdown]
# <h1 style="color: darkblue; text-align: center; font-family: Arial, sans-serif; font-size: 32px;">
#   Central tendency of measures Mean, median mode
# </h1>

# %%
#EXP NO: 2

# %%
#Aim: To understand and compute the central values of a dataset using mean, median, and mode for effective data summarization.

# %%
#Name: Raghuvir V. Anturkar 
#Roll no: 03
#sec: A
#subject: EMERGING TECH. LAB - I

# %%
import numpy as np
import pandas as pd
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
data = [65, 70, 75, 80, 85, 90, 75, 85, 95, 100]

# %%
arr = np.array(data)
print("Data as NumPy Array:", arr)
# Out:
# Data as NumPy Array: [ 65  70  75  80  85  90  75  85  95 100]

# %%
mean_val = np.mean(arr)
print("Mean:", mean_val)
# Out:
# Mean: 82.0

# %%
median_val = np.median(arr)
print("Median:", median_val)
# Out:
# Median: 82.5

# %%
series = pd.Series(arr)
mode_val = series.mode()
print("Mode:", mode_val.tolist())
# Out:
# Mode: [75, 85]

# %%
df = pd.DataFrame({'Marks': data})
print("Mean (Pandas):", df['Marks'].mean())
print("Median (Pandas):", df['Marks'].median())
print("Mode (Pandas):", df['Marks'].mode().tolist())
# Out:
# Mean (Pandas): 82.0
# Median (Pandas): 82.5
# Mode (Pandas): [75, 85]

# %%
import matplotlib.pyplot as plt

plt.hist(data, bins=5, color='lightblue', edgecolor='black')
plt.axvline(mean_val, color='red', linestyle='dashed', linewidth=2, label='Mean')
plt.axvline(median_val, color='green', linestyle='dashed', linewidth=2, label='Median')
for m in mode_val:
    plt.axvline(m, color='purple', linestyle='dotted', linewidth=2, label='Mode')
plt.legend()
plt.title('Distribution with Mean, Median, and Mode')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### ✅ Conclusion:
# This practical demonstrated how to calculate and interpret the mean, median, and mode of a dataset using NumPy and Pandas, and how these measures summarize central tendency in data.
